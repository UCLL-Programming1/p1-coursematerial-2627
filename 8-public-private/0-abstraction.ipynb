# %% [markdown]
# # Abstraction and Public Interfaces

# %% [markdown]
# ## In our daily lives
#
# Abstraction is part of our daily lives: our brains use it to make interacting with the world manageable.
#
# When you work on your laptop, you interact with it on a very high level of abstraction: you type on your keyboard and letters "magically" appear on your screen, you use your mouse or trackpad to move the cursor around and click on different GUI elements.
#
# While doing so, you're not thinking of the billions of instructions that are being executed by your laptop to render fonts, process data, play music, etc. You think even less about the logic gates built out of transistors on your CPU that furiously manipulate electrical signals that represent bits. And you certainly don't think about changes in quantum fields as spinny muons and charming leptons (or whatever those things are called) buzz around.
#
# Abstraction is all about hiding details and only focusing on the things that matter.

# %% [markdown]
# ## In Programming
#
# Back to the programming world.
#
# In programming we have abstraction as well. Take `print("Hello")` for example: internally, printing to the screen is quite an elaborate process that involves millions of instructions, manipulating electrical circuits and millions of little LED's on your screen.
#
# But that doesn't interest you. The only thing you care about is that `Hello` appears on the screen.
#
# There are only three things you need to know about the function `print`:
#
# - Its name.
# - Its parameters.
# - Its return value.
#
# Knowing this, you can use `print()` all day, every day, without having the slightest clue of how this function works under the hood.
#
# This is called the functions *public interface*. A function also contains a set of instructions, but those are implementation details and are *private*.
#
# We can visualize this as follows:
#
# ![Abstraction](../.assets/image-abstraction.svg)
#
# What we need to do is to make the complex implementation private (red) and only wrap it inside a simple public interface (green).

# %% [markdown]
# ## Safety
#
# Abstraction can also provide safety.
#
# Take, for example, a television. It contains plenty of electronics, but you're not supposed to touch those. Instead, the television comes with "public interface", i.e., a remote control. All interactions with your television should go through this remote control.
#
# If the television is well made, there is no combination of remote control buttons you could press that would *break* the television. The remote control should be 100% safe to use.
#
# However, tinkering with the internals of the television is a lot riskier. Even though you could probably change the channel by prodding the right circuit, prodding the wrong circuit could break your television.
#
# The same is true with code. The public interface should be made in such a way that
#
# - it's easy to use and understand; and
# - it cannot break the object.
