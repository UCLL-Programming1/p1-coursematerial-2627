# %% [markdown]
# # Welcome to Python!
#
# The document you're reading right now is a Jupyter notebook. In these types of notebooks, we can mix text explanations like this one with code blocks you can execute right in this very document. For example the next cell is code cell. If you hover over it you can see a `play` button on the left:
#
# When you click it, the code will run, and the cell will output any results of the code (in this case 'This is a code cell')

# %%
print("This is a code cell")

# %% [markdown]
# The following cell is an empty code cell. We made this cell so that you can now write your own code.
#
# Program it so that when you run it, it prints `Hello World!`. Then run it.

# %% [markdown]
# Congratulations! It may not seem like much, but unbeknownst to you, you just wrote your very first program! Thousands if not millions of students from all over the world over many decades have traditionally started their programming journey by writing this very program in their very first programming language: [Hello World](https://en.wikipedia.org/wiki/%22Hello,_World!%22_program)
#
# You have officially started to learn how to code!

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 10.1: Writing in a Python script file
#
# Writing code within the cells of this notebook is good for learning, but typically when we make python programs, we're going to write our Python code in a separate script. In the file [exercise_10_1_hello_world.py](concept-exercises/exercise_10_1_hello_world.py) (you can open this file by ctrl/cmd clicking the link) write the code that will print `"Hello World!"`.
#
# We wrote a test that you can run to make sure you did this correctly. You can run this test by executing the following cell (you don't need to understand how this cell works):

# %%
# code to run the tests
# !python3 -m pytest -q --tb=short concept-exercises/.tests/test_exercise_10_1_hello_world.py

# %% [markdown]
# > Note: in order for the test to be successful, you need to specify the messages exactly as in the example usage, even a space too little or too much will make the test fail!
